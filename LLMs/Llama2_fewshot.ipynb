# %%
# !pip install transformers datasets peft bitsandbytes accelerate --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.4 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### LOAD MODEL

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "ngoan/Llama-2-7b-vietnamese-20k"

tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    torch_dtype="auto")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/775 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/623 [00:00<?, ?B/s]
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]

# %% [markdown]
# ### BUILD PROMPT

# %%
def build_prompt(text):
    return f"""Văn bản sau là một tin tức. Hãy phân loại là:
- 0 nếu đáng tin (tin thật)
- 1 nếu không đáng tin (tin giả)

Chỉ trả lời **0** hoặc **1**. Không giải thích.

Ví dụ:
Văn bản: "Chính phủ công bố gói hỗ trợ 350 nghìn tỷ cho doanh nghiệp nhỏ."
Nhãn: 0

Văn bản: "Ca sĩ Hòa Minzy bị bắt vì buôn lậu vũ khí hạt nhân."
Nhãn: 1

Văn bản: "NASA xác nhận Trái Đất sắp va chạm với sao Diêm Vương vào tháng tới."
Nhãn: 1

Văn bản: \"{text}\"

Nhãn:"""

# %% [markdown]
# ### CLASSIFY NEWS

# %%
import torch
import gc

def classify(text):
    prompt = build_prompt(text)
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    try:
        with torch.no_grad():
            output = model.generate(
                **inputs,
                max_new_tokens=10,
                do_sample=False
            )

        # Chỉ lấy phần mô hình sinh ra (không tính prompt)
        decoded_only = tokenizer.decode(
            output[0][inputs['input_ids'].shape[1]:],
            skip_special_tokens=True
        ).strip()

        if not decoded_only:
            print("⚠️ Output rỗng từ mô hình.")
            return ""

        return decoded_only  # Trả về nguyên chuỗi để xử lý sau
    finally:
        # Luôn dọn dẹp bộ nhớ, kể cả khi lỗi
        del inputs, output
        torch.cuda.empty_cache()
        gc.collect()


classify('''
VNINDEX đạt 1500 điểm chỉ sau 3 tháng kể từ sự kiện thiên nga đen. Sốc quá. Vãi. Lừa đảo
''')
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# '0\nNhãn: 0'

# %% [markdown]
# ### PREDICT AND SAVE RESULT

# %%
import os
import gc
import torch
import pandas as pd
from tqdm import tqdm

test_path = '/content/drive/MyDrive/1.PROJECTS/[TeamPe][BIT][BGRA2025]/NLP/Code/reintel_dataset/test.csv'
result_path = "/content/drive/MyDrive/1.PROJECTS/[TeamPe][BIT][BGRA2025]/NLP/Code/LLMs/prediction_llamazero.csv"

#Đọc file
df = pd.read_csv(test_path)

# Giúp giảm phân mảnh RAM CUDA
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Khởi tạo danh sách lưu kết quả
predictions = []

# Đảm bảo dọn RAM trước khi chạy
torch.cuda.empty_cache()
gc.collect()

for idx, text in tqdm(enumerate(df["post_message"]), total=len(df), desc="Đang phân loại"):
    success = False
    retry_count = 0
    max_retry = 3  # cố gắng tối đa 3 lần nếu bị lỗi

    while not success and retry_count < max_retry:
        try:
            pred = classify(text)
            predictions.append(pred)
            success = True
        except torch.cuda.OutOfMemoryError as e:
            print(f"[{idx}] ❌ OOM: {e}, đang dọn bộ nhớ và thử lại ({retry_count + 1}/{max_retry})...")
            torch.cuda.empty_cache()
            gc.collect()
            retry_count += 1
        except Exception as e:
            print(f"[{idx}] ⚠️ Lỗi không xác định: {e}, trả về None")
            predictions.append(None)
            success = True  # vẫn tiếp tục vì lỗi không hồi được

    # Nếu thử nhiều lần vẫn fail → append None để không dừng toàn bộ
    if not success:
        print(f"[{idx}] ❌ Không thể phân loại sau {max_retry} lần thử. Ghi None.")
        predictions.append(None)

    # Tùy chọn: lưu tạm sau mỗi 10 mẫu để tránh mất dữ liệu
    if idx % 10 == 0 and idx > 0:
        df_temp = df.iloc[:idx + 1].copy()
        df_temp["predict"] = predictions
        df_temp.to_csv("temp_backup_predictions.csv", index=False)

# Gán kết quả vào DataFrame gốc
df["predict"] = predictions

# Lưu file cuối
df.to_csv(result_path, index=False)
print("✅ Đã phân loại xong toàn bộ văn bản.")
# Out:
# Đang phân loại:   0%|          | 0/486 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   0%|          | 1/486 [00:01<12:15,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   0%|          | 2/486 [00:03<15:00,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   1%|          | 3/486 [00:06<17:35,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   1%|          | 4/486 [00:08<17:32,  2.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   1%|          | 5/486 [00:10<16:48,  2.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   1%|          | 6/486 [00:11<15:00,  1.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   1%|▏         | 7/486 [00:13<15:01,  1.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   2%|▏         | 8/486 [00:15<13:50,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   2%|▏         | 9/486 [00:16<13:20,  1.68s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   2%|▏         | 10/486 [00:18<14:42,  1.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   2%|▏         | 11/486 [00:20<15:01,  1.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   2%|▏         | 12/486 [00:22<13:58,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   3%|▎         | 13/486 [00:24<14:06,  1.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [12] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:   3%|▎         | 14/486 [00:26<14:21,  1.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   3%|▎         | 15/486 [00:28<14:33,  1.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   3%|▎         | 16/486 [00:29<13:35,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   3%|▎         | 17/486 [00:31<13:25,  1.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   4%|▎         | 18/486 [00:33<14:41,  1.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   4%|▍         | 19/486 [00:35<14:06,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   4%|▍         | 20/486 [00:36<13:57,  1.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   4%|▍         | 21/486 [00:38<13:51,  1.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   5%|▍         | 22/486 [00:40<13:44,  1.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   5%|▍         | 23/486 [00:41<12:39,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   5%|▍         | 24/486 [00:42<11:33,  1.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   5%|▌         | 25/486 [00:44<11:10,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   5%|▌         | 26/486 [00:45<10:41,  1.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   6%|▌         | 27/486 [00:47<11:01,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   6%|▌         | 28/486 [00:48<11:14,  1.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   6%|▌         | 29/486 [00:49<10:33,  1.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   6%|▌         | 30/486 [00:51<10:19,  1.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   6%|▋         | 31/486 [00:52<10:08,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   7%|▋         | 32/486 [00:53<09:54,  1.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   7%|▋         | 33/486 [00:54<09:51,  1.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   7%|▋         | 34/486 [00:56<09:46,  1.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   7%|▋         | 35/486 [00:57<10:03,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   7%|▋         | 36/486 [00:58<10:13,  1.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   8%|▊         | 37/486 [01:00<11:35,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:   8%|▊         | 38/486 [01:02<10:44,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:
/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  28%|██▊       | 136/486 [03:32<08:13,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  28%|██▊       | 137/486 [03:33<08:05,  1.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  28%|██▊       | 138/486 [03:34<07:54,  1.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  29%|██▊       | 139/486 [03:36<07:49,  1.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  29%|██▉       | 140/486 [03:37<07:43,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  29%|██▉       | 141/486 [03:38<07:35,  1.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  29%|██▉       | 142/486 [03:40<07:38,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  29%|██▉       | 143/486 [03:42<08:55,  1.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [142] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  30%|██▉       | 144/486 [03:43<08:31,  1.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  30%|██▉       | 145/486 [03:44<08:03,  1.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  30%|███       | 146/486 [03:46<08:40,  1.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  30%|███       | 147/486 [03:47<08:19,  1.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  30%|███       | 148/486 [03:49<08:03,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  31%|███       | 149/486 [03:50<07:51,  1.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  31%|███       | 150/486 [03:52<08:30,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [149] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  31%|███       | 151/486 [03:53<08:23,  1.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  31%|███▏      | 152/486 [03:55<09:23,  1.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [151] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  31%|███▏      | 153/486 [03:57<08:48,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  32%|███▏      | 154/486 [03:59<09:33,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [153] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  32%|███▏      | 155/486 [04:00<08:57,  1.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  32%|███▏      | 156/486 [04:02<08:28,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  32%|███▏      | 157/486 [04:03<07:54,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  33%|███▎      | 158/486 [04:04<07:55,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  33%|███▎      | 159/486 [04:06<08:03,  1.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  33%|███▎      | 160/486 [04:08<09:27,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  33%|███▎      | 161/486 [04:09<08:51,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  33%|███▎      | 162/486 [04:11<08:30,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  34%|███▎      | 163/486 [04:12<08:19,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  34%|███▎      | 164/486 [04:14<07:59,  1.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  34%|███▍      | 165/486 [04:15<07:37,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  34%|███▍      | 166/486 [04:17<07:41,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  34%|███▍      | 167/486 [04:19<08:54,  1.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  35%|███▍      | 168/486 [04:20<08:51,  1.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  35%|███▍      | 169/486 [04:22<08:20,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  35%|███▍      | 170/486 [04:24<09:05,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [169] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  35%|███▌      | 171/486 [04:25<08:40,  1.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  35%|███▌      | 172/486 [04:27<08:12,  1.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  36%|███▌      | 173/486 [04:29<08:58,  1.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  36%|███▌      | 174/486 [04:30<08:28,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  36%|███▌      | 175/486 [04:32<08:06,  1.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  36%|███▌      | 176/486 [04:33<07:42,  1.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  36%|███▋      | 177/486 [04:35<08:10,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [176] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  37%|███▋      | 178/486 [04:36<07:47,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:
/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  86%|████████▋ | 420/486 [10:45<01:54,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [419] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  87%|████████▋ | 421/486 [10:46<01:46,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  87%|████████▋ | 422/486 [10:48<01:52,  1.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  87%|████████▋ | 423/486 [10:50<01:47,  1.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  87%|████████▋ | 424/486 [10:51<01:35,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  87%|████████▋ | 425/486 [10:54<01:53,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  88%|████████▊ | 426/486 [10:56<02:02,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  88%|████████▊ | 427/486 [10:57<01:48,  1.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  88%|████████▊ | 428/486 [10:59<01:37,  1.68s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  88%|████████▊ | 429/486 [11:00<01:29,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  88%|████████▊ | 430/486 [11:02<01:28,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  89%|████████▊ | 431/486 [11:03<01:30,  1.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [430] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  89%|████████▉ | 432/486 [11:04<01:11,  1.32s/it]
# [431] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  89%|████████▉ | 433/486 [11:07<01:38,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  89%|████████▉ | 434/486 [11:09<01:30,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  90%|████████▉ | 435/486 [11:10<01:22,  1.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  90%|████████▉ | 436/486 [11:11<01:17,  1.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  90%|████████▉ | 437/486 [11:13<01:11,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  90%|█████████ | 438/486 [11:14<01:06,  1.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  90%|█████████ | 439/486 [11:15<01:02,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  91%|█████████ | 440/486 [11:16<01:02,  1.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  91%|█████████ | 441/486 [11:18<01:00,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  91%|█████████ | 442/486 [11:19<01:00,  1.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  91%|█████████ | 443/486 [11:21<00:59,  1.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  91%|█████████▏| 444/486 [11:22<00:57,  1.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  92%|█████████▏| 445/486 [11:23<00:56,  1.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  92%|█████████▏| 446/486 [11:25<01:03,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [445] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# Đang phân loại:  92%|█████████▏| 447/486 [11:27<00:58,  1.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  92%|█████████▏| 448/486 [11:28<00:55,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  92%|█████████▏| 449/486 [11:30<00:57,  1.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  93%|█████████▎| 450/486 [11:32<01:04,  1.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  93%|█████████▎| 451/486 [11:34<01:04,  1.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  93%|█████████▎| 452/486 [11:36<00:58,  1.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  93%|█████████▎| 453/486 [11:37<00:51,  1.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  93%|█████████▎| 454/486 [11:38<00:47,  1.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  94%|█████████▎| 455/486 [11:39<00:45,  1.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  94%|█████████▍| 456/486 [11:41<00:42,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  94%|█████████▍| 457/486 [11:44<00:52,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  94%|█████████▍| 458/486 [11:45<00:51,  1.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  94%|█████████▍| 459/486 [11:47<00:46,  1.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  95%|█████████▍| 460/486 [11:48<00:42,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  95%|█████████▍| 461/486 [11:50<00:38,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  95%|█████████▌| 462/486 [11:51<00:37,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  95%|█████████▌| 463/486 [11:53<00:36,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  95%|█████████▌| 464/486 [11:54<00:33,  1.54s/it]
# [463] ⚠️ Lỗi không xác định: cannot access local variable 'output' where it is not associated with a value, trả về None
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  96%|█████████▌| 465/486 [11:56<00:34,  1.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  96%|█████████▌| 466/486 [11:57<00:30,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  96%|█████████▌| 467/486 [11:59<00:27,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  96%|█████████▋| 468/486 [12:00<00:25,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  97%|█████████▋| 469/486 [12:01<00:23,  1.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  97%|█████████▋| 470/486 [12:03<00:22,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  97%|█████████▋| 471/486 [12:04<00:20,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  97%|█████████▋| 472/486 [12:06<00:20,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  97%|█████████▋| 473/486 [12:07<00:18,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  98%|█████████▊| 474/486 [12:09<00:17,  1.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  98%|█████████▊| 475/486 [12:10<00:15,  1.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  98%|█████████▊| 476/486 [12:11<00:14,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  98%|█████████▊| 477/486 [12:13<00:12,  1.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  98%|█████████▊| 478/486 [12:14<00:12,  1.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  99%|█████████▊| 479/486 [12:16<00:11,  1.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  99%|█████████▉| 480/486 [12:18<00:09,  1.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  99%|█████████▉| 481/486 [12:19<00:07,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  99%|█████████▉| 482/486 [12:20<00:05,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại:  99%|█████████▉| 483/486 [12:23<00:05,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại: 100%|█████████▉| 484/486 [12:24<00:03,  1.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại: 100%|█████████▉| 485/486 [12:27<00:01,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Đang phân loại: 100%|██████████| 486/486 [12:29<00:00,  1.54s/it]
# ✅ Đã phân loại xong toàn bộ văn bản.

# %%
def map_to_label(pred):
    if not isinstance(pred, str):
        return 0
    text = pred.lower()
    if "giả" in text or "fake" in text or "sai sự thật" in text or text.strip().startswith("1"):
        return 1
    return 0


df["label_mapped"] = df["predict"].apply(map_to_label)
df.to_csv(result_path, index=False)

# %% [markdown]
# ### VALIDATE THE LLM MODEL

# %%
acc = (df['label_mapped'] == df['label']).mean()
print(f'Accuracy: {acc:.4f}')
# Out:
# Accuracy: 0.6749

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# Đọc dữ liệu từ file CSV
df = pd.read_csv(result_path)

# Giả sử label và predict là kiểu số nguyên (0 hoặc 1)
y_true = df['label']
y_pred = df['label_mapped']

# Tính các chỉ số đánh giá
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
auc = roc_auc_score(y_true, y_pred)  # Ước lượng từ nhãn nhị phân

# In kết quả ra màn hình
print("🔹 Đánh giá mô hình:")
print(f"  - Accuracy : {accuracy:.4f}")
print(f"  - Precision: {precision:.4f}")
print(f"  - Recall   : {recall:.4f}")
print(f"  - F1-score : {f1:.4f}")
print(f"  - AUC      : {auc:.4f}")

# Vẽ ma trận nhầm lẫn
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Giả', 'Thật'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Ma trận nhầm lẫn (Confusion Matrix)")
plt.show()
# Out:
# 🔹 Đánh giá mô hình:
#   - Accuracy : 0.6749
#   - Precision: 0.1780
#   - Recall   : 0.2561
#   - F1-score : 0.2100
#   - AUC      : 0.5080
